# %% [markdown]
# <a href="https://colab.research.google.com/github/lcbjrrr/algojust/blob/main/NB00_data_and_stas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Analysis

# %%
import pandas as pd
grades = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/algojust/refs/heads/main/grades%20-%20ok.csv')
grades.head(3)
# Out:
#   Course Student  AP1  AP2  AP3  Grade Score
# 0    ADM    Finn   90   90   90     90     A
# 1    ADM    Jack   60   40  100     60     D
# 2    LAW     Leo   40   30   40     36     E

# %%
grades.tail(2)
# Out:
#    Course Student  AP1  AP2  AP3  Grade Score
# 10    ADM   Quinn   80   70   60     72     C
# 11    ADM    Wren   45   40   40     42     E

# %%
grades['AP1']
# Out:
# 0      90
# 1      60
# 2      40
# 3      80
# 4      75
# 5      60
# 6      80
# 7      75
# 8      60
# 9     100
# 10     80
# 11     45
# Name: AP1, dtype: int64

# %%
grades[grades['Score']=='A']
# Out:
#   Course Student  AP1  AP2  AP3  Grade Score
# 0    ADM    Finn   90   90   90     90     A
# 7    LAW    June   75  100   95     89     A
# 9    LAW    Rose  100   95   95     97     A

# %%
grades['AP1'] * 0.4 + grades['AP2'] * 0.4 + grades['AP3'] * 0.2
# Out:
# 0     90.0
# 1     60.0
# 2     36.0
# 3     86.0
# 4     81.0
# 5     54.0
# 6     72.0
# 7     89.0
# 8     78.0
# 9     97.0
# 10    72.0
# 11    42.0
# dtype: float64

# %%
average_grade_course = grades.groupby('Course')['Grade'].mean()
average_grade_course
# Out:
# Course
# ADM    67.2
# ECO    79.5
# LAW    72.4
# Name: Grade, dtype: float64

# %%
average_grade_course.plot(kind='bar')
# Out:
# <Axes: xlabel='Course'>

# %%
student_per_course = grades.groupby('Course')['Student'].count()
student_per_course.plot(kind='pie')
# Out:
# <Axes: ylabel='Student'>

# %%
covid = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/algojust/refs/heads/main/covid19.csv')
covid.index = pd.to_datetime(covid['date'])
covid=covid.drop('date', axis=1)
covid.plot()
# Out:
# /tmp/ipython-input-3431995168.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   covid.index = pd.to_datetime(covid['date'])
# <Axes: xlabel='date'>

# %% [markdown]
# ## Stats

# %%
cat_freq = grades['Score'].value_counts()
print(cat_freq)
cat_freq.plot(kind='bar')
# Out:
# Score
# A    3
# E    3
# C    3
# B    2
# D    1
# Name: count, dtype: int64
# <Axes: xlabel='Score'>

# %%
import seaborn as sns
sns.displot(grades['Grade'],bins=[0,50,70,90,100])

# %%
grades['Grade'].describe()
# Out:
# count    12.000000
# mean     71.416667
# std      19.565546
# min      36.000000
# 25%      58.500000
# 50%      75.000000
# 75%      86.750000
# max      97.000000
# Name: Grade, dtype: float64

# %%
sns.boxplot(grades['Grade'])
# Out:
# <Axes: ylabel='Grade'>
